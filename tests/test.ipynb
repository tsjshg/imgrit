# %%
from PIL import Image
import imgrit

# %%
imgrit.__version__
# Out:
# '0.2.0'

# %%
my_image = Image.open("../images/original.jpg")

# %%
voronoi_mosaic, error = imgrit.voronoi_mosaic(my_image, 50, random=True, verbose=True)

# %%
voronoi_mosaic
# Out:
# <PIL.Image.Image image mode=RGB size=775x775>

# %%
error
# Out:
# np.float64(88.8846285119667)

# %%
imgrit.warhol_effect(my_image)
# Out:
# <PIL.Image.Image image mode=RGB size=775x775>
